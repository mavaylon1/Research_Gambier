# %%
import glob
from skimage.io import imread, imsave
import matplotlib.pyplot as plt
import numpy as np

img_names = sorted(glob.glob("/Users/mavaylon/Downloads/Gambier_eq_filtered2/*.png"))
for name in img_names:
    print(name)
    im = imread(name)
    print(im.shape)
    #img = cv.imread(path)
    normalizedImg = np.zeros((512, 512))
    normalizedImg = cv.normalize(im,  normalizedImg, 0, 255, cv.NORM_MINMAX)
#     cv.imshow('dst_rt', normalizedImg)
#     cv.waitKey(0)
#     cv.destroyAllWindows()
    imsave(name,im)
# Out:
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0000.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0001.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0002.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0003.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0004.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0005.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0006.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0007.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0008.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0009.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0010.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0011.png
# (512, 512)
# /Users/mavaylon/Downloads/Gambier_eq_filtered2/image_0012.png
# ...

# %%
import cv2 as cv

# %%
img_names2 = sorted(glob.glob("/Users/mavaylon/Downloads/BP_eq_filtered_2/*.png"))
t=img_names2[0]
im = imread(t)
normalizedImg = np.zeros((512, 512))
normalizedImg = cv.normalize(im,  normalizedImg, 0, 255, cv.NORM_MINMAX)
im

# %%
import glob
from skimage.io import imread, imsave
import matplotlib.pyplot as plt
import numpy as np

img_names = sorted(glob.glob("/Users/mavaylon/Downloads/BP_eq_filtered3/*.png"))
for name in img_names:
    print(name)
    im = imread(name)
    print(im.shape)
    #im[im>0]=1
    im = im/255
    im.dtype = np.uint8
    imsave(name,im)
# Out:
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0000.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0001.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0002.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0003.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0004.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0005.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0006.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0007.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0008.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0009.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0010.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0011.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0012.png
# (500, 500)
# /Users/mavaylon/Downloads/BP_eq_filtered3/image_0013.png
# ...

# %%
img_namesbp = sorted(glob.glob("/Users/mavaylon/Downloads/BP_eq_filtered3/*.png"))
imread(img_namesbp[0])/255
# Out:
# array([[0.34117647, 0.34117647, 0.34117647, ..., 0.83529412, 0.83529412,
#         0.24705882],
#        [0.85098039, 0.84705882, 0.84705882, ..., 0.6       , 0.85098039,
#         0.24705882],
#        [0.08627451, 0.08627451, 0.08627451, ..., 0.6       , 0.85098039,
#         0.24705882],
#        ...,
#        [0.98431373, 0.98039216, 0.98039216, ..., 0.10588235, 0.85882353,
#         0.24705882],
#        [0.23137255, 0.23137255, 0.23137255, ..., 0.83137255, 0.89411765,
#         0.24705882],
#        [0.35686275, 0.35686275, 0.35686275, ..., 0.48627451, 0.9254902 ,
#         0.24705882]])

# %%
img_names4 = sorted(glob.glob("/Users/mavaylon/Downloads/BP_eq_filtered/*.png"))
imread(img_names4[0])/255
# Out:
# array([[0.36470588, 0.39607843, 0.35294118, ..., 0.40392157, 0.39607843,
#         0.34117647],
#        [0.38823529, 0.4       , 0.37254902, ..., 0.39607843, 0.37254902,
#         0.4       ],
#        [0.34509804, 0.39215686, 0.39607843, ..., 0.39215686, 0.38823529,
#         0.4       ],
#        ...,
#        [0.84313725, 0.85490196, 0.85882353, ..., 0.40392157, 0.37647059,
#         0.42352941],
#        [0.85098039, 0.84705882, 0.85490196, ..., 0.42745098, 0.38431373,
#         0.65098039],
#        [0.85490196, 0.8745098 , 0.87058824, ..., 0.80784314, 0.85098039,
#         0.89019608]])

# %%
gamb='/Users/mavaylon/Research/Research_Gambier/Data/gamb_orig_copy/'

img_names = sorted(glob.glob("/Users/mavaylon/Downloads/BP_eq_filtered3/*.png"))
for name in img_names:
    print(name)
    im = imread(name)
    print(im.shape)
    #im[im>0]=1
    im = im/255
    im.dtype = np.uint8
    imsave(name,im)
