# %%
import sys
sys.path.insert(1, './src')
from crfrnn_model import get_crfrnn_model_def
import util
from skimage.io import imread
import matplotlib.pyplot as plt

# %%
input_file = 'image.jpg'
output_file = 'labels.png'

input_image = imread('image.jpg')
plt.imshow(input_image)

# %%
# Download the model from https://goo.gl/ciEYZi
saved_model_path = 'crfrnn_keras_model.h5'

model = get_crfrnn_model_def()
model.load_weights(saved_model_path)

img_data, img_h, img_w, size = util.get_preprocessed_image(input_file)
probs = model.predict(img_data, verbose=False)[0]
segmentation = util.get_label_image(probs, img_h, img_w, size)
segmentation.save(output_file)

output_image = imread('labels.png')
plt.imshow(output_image)

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Input, ZeroPadding2D, \
    Dropout, Conv2DTranspose, Cropping2D, Add, UpSampling2D
from keras.layers.merge import concatenate
from keras_segmentation.models.model_utils import get_segmentation_model

input_height = 512
input_width = 512
n_classes = 2
channels = 3

img_input = Input(shape=(input_height,input_width, channels))

conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(img_input)
conv1 = Dropout(0.2)(conv1)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D((2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Dropout(0.2)(conv2)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D((2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Dropout(0.2)(conv3)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)

up1 = concatenate([UpSampling2D((2, 2))(conv3), conv2], axis=-1)
conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(up1)
conv4 = Dropout(0.2)(conv4)
conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv4)

up2 = concatenate([UpSampling2D((2, 2))(conv4), conv1], axis=-1)
conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(up2)
conv5 = Dropout(0.2)(conv5)
conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv5)

out = Conv2D( n_classes, (1, 1) , padding='same')(conv5)

model_1 = get_segmentation_model(img_input ,  out ) # this would build the segmentation model

# %%
model_1.train(train_images = "data/BeadPack/train_images/", 
            train_annotations="data/BeadPack/train_segmentation/",
            checkpoints_path="checkpoints/model_1/",
            epochs=5)
# Out:
#   4%|▍         | 18/400 [00:00<00:02, 174.37it/s]
# Verifying training dataset
# 100%|██████████| 400/400 [00:02<00:00, 177.09it/s]
# Dataset verified!
# Epoch 1/5
# 512/512 [==============================] - ETA: 0s - loss: 0.7286 - accuracy: 0.8033saved  checkpoints/model_1/.0
# 512/512 [==============================] - 977s 2s/step - loss: 0.7286 - accuracy: 0.8033
# Epoch 2/5
# 512/512 [==============================] - ETA: 0s - loss: 0.1394 - accuracy: 0.9592saved  checkpoints/model_1/.1
# 512/512 [==============================] - 953s 2s/step - loss: 0.1394 - accuracy: 0.9592
# Epoch 3/5
# 512/512 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9710saved  checkpoints/model_1/.2
# 512/512 [==============================] - 951s 2s/step - loss: 0.0949 - accuracy: 0.9710
# Epoch 4/5
# 512/512 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9762saved  checkpoints/model_1/.3
# 512/512 [==============================] - 954s 2s/step - loss: 0.0746 - accuracy: 0.9762
# Epoch 5/5
# 512/512 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9795saved  checkpoints/model_1/.4
# 512/512 [==============================] - 955s 2s/step - loss: 0.0628 - accuracy: 0.9795

# %%
import glob

img_names = sorted(glob.glob("./data/BeadPack/val_images/*.png"))


for name in img_names:
    out_name = "./outputs_model_1/" + name.split('/')[-1]
    print(out_name)
    out = model_1.predict_segmentation(inp=name, out_fname=out_name)
# Out:
# ./outputs_model_1/image_0400.png
# ./outputs_model_1/image_0401.png
# ./outputs_model_1/image_0402.png
# ./outputs_model_1/image_0403.png
# ./outputs_model_1/image_0404.png
# ./outputs_model_1/image_0405.png
# ./outputs_model_1/image_0406.png
# ./outputs_model_1/image_0407.png
# ./outputs_model_1/image_0408.png
# ./outputs_model_1/image_0409.png
# ./outputs_model_1/image_0410.png
# ./outputs_model_1/image_0411.png
# ./outputs_model_1/image_0412.png
# ./outputs_model_1/image_0413.png
# ./outputs_model_1/image_0414.png
# ./outputs_model_1/image_0415.png
# ./outputs_model_1/image_0416.png
# ./outputs_model_1/image_0417.png
# ./outputs_model_1/image_0418.png
# ./outputs_model_1/image_0419.png
# ./outputs_model_1/image_0420.png
# ./outputs_model_1/image_0421.png
# ./outputs_model_1/image_0422.png
# ./outputs_model_1/image_0423.png
# ./outputs_model_1/image_0424.png
# ./outputs_model_1/image_0425.png
# ./outputs_model_1/image_0426.png
# ./outputs_model_1/image_0427.png
# ./outputs_model_1/image_0428.png
# ./outputs_model_1/image_0429.png
# ./outputs_model_1/image_0430.png
# ./outputs_model_1/image_0431.png
# ./outputs_model_1/image_0432.png
# ./outputs_model_1/image_0433.png
# ./outputs_model_1/image_0434.png
# ./outputs_model_1/image_0435.png
# ./outputs_model_1/image_0436.png
# ./outputs_model_1/image_0437.png
# ./outputs_model_1/image_0438.png
# ./outputs_model_1/image_0439.png
# ./outputs_model_1/image_0440.png
# ./outputs_model_1/image_0441.png
# ./outputs_model_1/image_0442.png
# ./outputs_model_1/image_0443.png
# ./outputs_model_1/image_0444.png
# ./outputs_model_1/image_0445.png
# ./outputs_model_1/image_0446.png
# ./outputs_model_1/image_0447.png
# ./outputs_model_1/image_0448.png
# ./outputs_model_1/image_0449.png
# ./outputs_model_1/image_0450.png
# ./outputs_model_1/image_0451.png
# ./outputs_model_1/image_0452.png
# ./outputs_model_1/image_0453.png
# ./outputs_model_1/image_0454.png
# ./outputs_model_1/image_0455.png
# ./outputs_model_1/image_0456.png
# ./outputs_model_1/image_0457.png
# ./outputs_model_1/image_0458.png
# ./outputs_model_1/image_0459.png
# ./outputs_model_1/image_0460.png
# ./outputs_model_1/image_0461.png
# ./outputs_model_1/image_0462.png
# ./outputs_model_1/image_0463.png
# ./outputs_model_1/image_0464.png
# ./outputs_model_1/image_0465.png
# ./outputs_model_1/image_0466.png
# ./outputs_model_1/image_0467.png
# ./outputs_model_1/image_0468.png
# ./outputs_model_1/image_0469.png
# ./outputs_model_1/image_0470.png
# ./outputs_model_1/image_0471.png
# ./outputs_model_1/image_0472.png
# ./outputs_model_1/image_0473.png
# ./outputs_model_1/image_0474.png
# ./outputs_model_1/image_0475.png
# ./outputs_model_1/image_0476.png
# ./outputs_model_1/image_0477.png
# ./outputs_model_1/image_0478.png
# ./outputs_model_1/image_0479.png
# ./outputs_model_1/image_0480.png
# ./outputs_model_1/image_0481.png
# ./outputs_model_1/image_0482.png
# ./outputs_model_1/image_0483.png
# ./outputs_model_1/image_0484.png
# ./outputs_model_1/image_0485.png
# ./outputs_model_1/image_0486.png
# ./outputs_model_1/image_0487.png
# ./outputs_model_1/image_0488.png
# ./outputs_model_1/image_0489.png
# ./outputs_model_1/image_0490.png
# ./outputs_model_1/image_0491.png
# ./outputs_model_1/image_0492.png
# ./outputs_model_1/image_0493.png
# ./outputs_model_1/image_0494.png
# ./outputs_model_1/image_0495.png
# ./outputs_model_1/image_0496.png
# ./outputs_model_1/image_0497.png
# ./outputs_model_1/image_0498.png
# ./outputs_model_1/image_0499.png
# ./outputs_model_1/image_0500.png
# ./outputs_model_1/image_0501.png
# ./outputs_model_1/image_0502.png
# ./outputs_model_1/image_0503.png
# ./outputs_model_1/image_0504.png
# ./outputs_model_1/image_0505.png
# ./outputs_model_1/image_0506.png
# ./outputs_model_1/image_0507.png
# ./outputs_model_1/image_0508.png
# ./outputs_model_1/image_0509.png
# ./outputs_model_1/image_0510.png
# ./outputs_model_1/image_0511.png

# %%
import glob

img_names = sorted(glob.glob("./data/Sandstone/Filtered/*.png"))


for name in img_names:
    out_name = "./outputs_model_1/sandstone/" + name.split('/')[-1]
    print(out_name)
    out = model_1.predict_segmentation(inp=name, out_fname=out_name)
# Out:
# ./outputs_model_1/sandstone/image000.png
# ./outputs_model_1/sandstone/image001.png
# ./outputs_model_1/sandstone/image002.png
# ./outputs_model_1/sandstone/image003.png
# ./outputs_model_1/sandstone/image004.png
# ./outputs_model_1/sandstone/image005.png
# ./outputs_model_1/sandstone/image006.png
# ./outputs_model_1/sandstone/image007.png
# ./outputs_model_1/sandstone/image008.png
# ./outputs_model_1/sandstone/image009.png
# ./outputs_model_1/sandstone/image010.png
# ./outputs_model_1/sandstone/image011.png
# ./outputs_model_1/sandstone/image012.png
# ./outputs_model_1/sandstone/image013.png
# ./outputs_model_1/sandstone/image014.png
# ./outputs_model_1/sandstone/image015.png
# ./outputs_model_1/sandstone/image016.png
# ./outputs_model_1/sandstone/image017.png
# ./outputs_model_1/sandstone/image018.png
# ./outputs_model_1/sandstone/image019.png
# ./outputs_model_1/sandstone/image020.png
# ./outputs_model_1/sandstone/image021.png
# ./outputs_model_1/sandstone/image022.png
# ./outputs_model_1/sandstone/image023.png
# ./outputs_model_1/sandstone/image024.png
# ./outputs_model_1/sandstone/image025.png
# ./outputs_model_1/sandstone/image026.png
# ./outputs_model_1/sandstone/image027.png
# ./outputs_model_1/sandstone/image028.png
# ./outputs_model_1/sandstone/image029.png
# ./outputs_model_1/sandstone/image030.png
# ./outputs_model_1/sandstone/image031.png
# ./outputs_model_1/sandstone/image032.png
# ./outputs_model_1/sandstone/image033.png
# ./outputs_model_1/sandstone/image034.png
# ./outputs_model_1/sandstone/image035.png
# ./outputs_model_1/sandstone/image036.png
# ./outputs_model_1/sandstone/image037.png
# ./outputs_model_1/sandstone/image038.png
# ./outputs_model_1/sandstone/image039.png
# ./outputs_model_1/sandstone/image040.png
# ./outputs_model_1/sandstone/image041.png
# ./outputs_model_1/sandstone/image042.png
# ./outputs_model_1/sandstone/image043.png
# ./outputs_model_1/sandstone/image044.png
# ./outputs_model_1/sandstone/image045.png
# ./outputs_model_1/sandstone/image046.png
# ./outputs_model_1/sandstone/image047.png
# ./outputs_model_1/sandstone/image048.png
# ./outputs_model_1/sandstone/image049.png
# ./outputs_model_1/sandstone/image050.png
# ./outputs_model_1/sandstone/image051.png
# ./outputs_model_1/sandstone/image052.png
# ./outputs_model_1/sandstone/image053.png
# ./outputs_model_1/sandstone/image054.png
# ./outputs_model_1/sandstone/image055.png
# ./outputs_model_1/sandstone/image056.png
# ./outputs_model_1/sandstone/image057.png
# ./outputs_model_1/sandstone/image058.png
# ./outputs_model_1/sandstone/image059.png
# ./outputs_model_1/sandstone/image060.png
# ./outputs_model_1/sandstone/image061.png
# ./outputs_model_1/sandstone/image062.png
# ./outputs_model_1/sandstone/image063.png
# ./outputs_model_1/sandstone/image064.png
# ./outputs_model_1/sandstone/image065.png
# ./outputs_model_1/sandstone/image066.png
# ./outputs_model_1/sandstone/image067.png
# ./outputs_model_1/sandstone/image068.png
# ./outputs_model_1/sandstone/image069.png
# ./outputs_model_1/sandstone/image070.png
# ./outputs_model_1/sandstone/image071.png
# ./outputs_model_1/sandstone/image072.png
# ./outputs_model_1/sandstone/image073.png
# ./outputs_model_1/sandstone/image074.png
# ./outputs_model_1/sandstone/image075.png
# ./outputs_model_1/sandstone/image076.png
# ./outputs_model_1/sandstone/image077.png
# ./outputs_model_1/sandstone/image078.png
# ./outputs_model_1/sandstone/image079.png
# ./outputs_model_1/sandstone/image080.png
# ./outputs_model_1/sandstone/image081.png
# ./outputs_model_1/sandstone/image082.png
# ./outputs_model_1/sandstone/image083.png
# ./outputs_model_1/sandstone/image084.png
# ./outputs_model_1/sandstone/image085.png
# ./outputs_model_1/sandstone/image086.png
# ./outputs_model_1/sandstone/image087.png
# ./outputs_model_1/sandstone/image088.png
# ./outputs_model_1/sandstone/image089.png
# ./outputs_model_1/sandstone/image090.png
# ./outputs_model_1/sandstone/image091.png
# ./outputs_model_1/sandstone/image092.png
# ./outputs_model_1/sandstone/image093.png
# ./outputs_model_1/sandstone/image094.png
# ./outputs_model_1/sandstone/image095.png
# ./outputs_model_1/sandstone/image096.png
# ./outputs_model_1/sandstone/image097.png
# ./outputs_model_1/sandstone/image098.png
# ./outputs_model_1/sandstone/image099.png
# ./outputs_model_1/sandstone/image100.png
# ./outputs_model_1/sandstone/image101.png
# ./outputs_model_1/sandstone/image102.png
# ./outputs_model_1/sandstone/image103.png
# ./outputs_model_1/sandstone/image104.png
# ./outputs_model_1/sandstone/image105.png
# ./outputs_model_1/sandstone/image106.png
# ./outputs_model_1/sandstone/image107.png
# ./outputs_model_1/sandstone/image108.png
# ./outputs_model_1/sandstone/image109.png
# ./outputs_model_1/sandstone/image110.png
# ./outputs_model_1/sandstone/image111.png
# ./outputs_model_1/sandstone/image112.png
# ./outputs_model_1/sandstone/image113.png
# ./outputs_model_1/sandstone/image114.png
# ./outputs_model_1/sandstone/image115.png
# ./outputs_model_1/sandstone/image116.png
# ./outputs_model_1/sandstone/image117.png
# ./outputs_model_1/sandstone/image118.png
# ./outputs_model_1/sandstone/image119.png
# ./outputs_model_1/sandstone/image120.png
# ./outputs_model_1/sandstone/image121.png
# ./outputs_model_1/sandstone/image122.png
# ./outputs_model_1/sandstone/image123.png
# ./outputs_model_1/sandstone/image124.png
# ./outputs_model_1/sandstone/image125.png
# ./outputs_model_1/sandstone/image126.png
# ./outputs_model_1/sandstone/image127.png
# ./outputs_model_1/sandstone/image128.png
# ./outputs_model_1/sandstone/image129.png
# ./outputs_model_1/sandstone/image130.png
# ./outputs_model_1/sandstone/image131.png
# ./outputs_model_1/sandstone/image132.png
# ./outputs_model_1/sandstone/image133.png
# ./outputs_model_1/sandstone/image134.png
# ./outputs_model_1/sandstone/image135.png
# ./outputs_model_1/sandstone/image136.png
# ./outputs_model_1/sandstone/image137.png
# ./outputs_model_1/sandstone/image138.png
# ./outputs_model_1/sandstone/image139.png
# ./outputs_model_1/sandstone/image140.png
# ./outputs_model_1/sandstone/image141.png
# ./outputs_model_1/sandstone/image142.png
# ./outputs_model_1/sandstone/image143.png
# ./outputs_model_1/sandstone/image144.png
# ./outputs_model_1/sandstone/image145.png
# ./outputs_model_1/sandstone/image146.png
# ./outputs_model_1/sandstone/image147.png
# ./outputs_model_1/sandstone/image148.png
# ./outputs_model_1/sandstone/image149.png
# ./outputs_model_1/sandstone/image150.png
# ./outputs_model_1/sandstone/image151.png
# ./outputs_model_1/sandstone/image152.png
# ./outputs_model_1/sandstone/image153.png
# ./outputs_model_1/sandstone/image154.png
# ./outputs_model_1/sandstone/image155.png
# ./outputs_model_1/sandstone/image156.png
# ./outputs_model_1/sandstone/image157.png
# ./outputs_model_1/sandstone/image158.png
# ./outputs_model_1/sandstone/image159.png
# ./outputs_model_1/sandstone/image160.png
# ./outputs_model_1/sandstone/image161.png
# ./outputs_model_1/sandstone/image162.png
# ./outputs_model_1/sandstone/image163.png
# ./outputs_model_1/sandstone/image164.png
# ./outputs_model_1/sandstone/image165.png
# ./outputs_model_1/sandstone/image166.png
# ./outputs_model_1/sandstone/image167.png
# ./outputs_model_1/sandstone/image168.png
# ./outputs_model_1/sandstone/image169.png
# ./outputs_model_1/sandstone/image170.png
# ./outputs_model_1/sandstone/image171.png
# ./outputs_model_1/sandstone/image172.png
# ./outputs_model_1/sandstone/image173.png
# ./outputs_model_1/sandstone/image174.png
# ./outputs_model_1/sandstone/image175.png
# ./outputs_model_1/sandstone/image176.png
# ./outputs_model_1/sandstone/image177.png
# ./outputs_model_1/sandstone/image178.png
# ./outputs_model_1/sandstone/image179.png
# ./outputs_model_1/sandstone/image180.png
# ./outputs_model_1/sandstone/image181.png
# ./outputs_model_1/sandstone/image182.png
# ./outputs_model_1/sandstone/image183.png
# ./outputs_model_1/sandstone/image184.png
# ./outputs_model_1/sandstone/image185.png
# ./outputs_model_1/sandstone/image186.png
# ./outputs_model_1/sandstone/image187.png
# ./outputs_model_1/sandstone/image188.png
# ./outputs_model_1/sandstone/image189.png
# ./outputs_model_1/sandstone/image190.png
# ./outputs_model_1/sandstone/image191.png
# ./outputs_model_1/sandstone/image192.png
# ./outputs_model_1/sandstone/image193.png
# ./outputs_model_1/sandstone/image194.png
# ./outputs_model_1/sandstone/image195.png
# ./outputs_model_1/sandstone/image196.png
# ./outputs_model_1/sandstone/image197.png
# ./outputs_model_1/sandstone/image198.png
# ./outputs_model_1/sandstone/image199.png
# ./outputs_model_1/sandstone/image200.png
# ./outputs_model_1/sandstone/image201.png
# ./outputs_model_1/sandstone/image202.png
# ./outputs_model_1/sandstone/image203.png
# ./outputs_model_1/sandstone/image204.png
# ./outputs_model_1/sandstone/image205.png
# ./outputs_model_1/sandstone/image206.png
# ./outputs_model_1/sandstone/image207.png
# ./outputs_model_1/sandstone/image208.png
# ./outputs_model_1/sandstone/image209.png
# ./outputs_model_1/sandstone/image210.png
# ./outputs_model_1/sandstone/image211.png
# ./outputs_model_1/sandstone/image212.png
# ./outputs_model_1/sandstone/image213.png
# ./outputs_model_1/sandstone/image214.png
# ./outputs_model_1/sandstone/image215.png
# ./outputs_model_1/sandstone/image216.png
# ./outputs_model_1/sandstone/image217.png
# ./outputs_model_1/sandstone/image218.png
# ./outputs_model_1/sandstone/image219.png
# ./outputs_model_1/sandstone/image220.png
# ./outputs_model_1/sandstone/image221.png
# ./outputs_model_1/sandstone/image222.png
# ./outputs_model_1/sandstone/image223.png
# ./outputs_model_1/sandstone/image224.png
# ./outputs_model_1/sandstone/image225.png
# ./outputs_model_1/sandstone/image226.png
# ./outputs_model_1/sandstone/image227.png
# ./outputs_model_1/sandstone/image228.png
# ./outputs_model_1/sandstone/image229.png
# ./outputs_model_1/sandstone/image230.png
# ./outputs_model_1/sandstone/image231.png
# ./outputs_model_1/sandstone/image232.png
# ./outputs_model_1/sandstone/image233.png
# ./outputs_model_1/sandstone/image234.png
# ./outputs_model_1/sandstone/image235.png
# ./outputs_model_1/sandstone/image236.png
# ./outputs_model_1/sandstone/image237.png
# ./outputs_model_1/sandstone/image238.png
# ./outputs_model_1/sandstone/image239.png
# ./outputs_model_1/sandstone/image240.png
# ./outputs_model_1/sandstone/image241.png
# ./outputs_model_1/sandstone/image242.png
# ./outputs_model_1/sandstone/image243.png
# ./outputs_model_1/sandstone/image244.png
# ./outputs_model_1/sandstone/image245.png
# ./outputs_model_1/sandstone/image246.png
# ./outputs_model_1/sandstone/image247.png
# ./outputs_model_1/sandstone/image248.png
# ./outputs_model_1/sandstone/image249.png
# ./outputs_model_1/sandstone/image250.png
# ./outputs_model_1/sandstone/image251.png
# ./outputs_model_1/sandstone/image252.png
# ./outputs_model_1/sandstone/image253.png
# ./outputs_model_1/sandstone/image254.png
# ./outputs_model_1/sandstone/image255.png
# ./outputs_model_1/sandstone/image256.png
# ./outputs_model_1/sandstone/image257.png
# ./outputs_model_1/sandstone/image258.png
# ./outputs_model_1/sandstone/image259.png
# ./outputs_model_1/sandstone/image260.png
# ./outputs_model_1/sandstone/image261.png
# ./outputs_model_1/sandstone/image262.png
# ./outputs_model_1/sandstone/image263.png
# ./outputs_model_1/sandstone/image264.png
# ./outputs_model_1/sandstone/image265.png
# ./outputs_model_1/sandstone/image266.png
# ./outputs_model_1/sandstone/image267.png
# ./outputs_model_1/sandstone/image268.png
# ./outputs_model_1/sandstone/image269.png
# ./outputs_model_1/sandstone/image270.png
# ./outputs_model_1/sandstone/image271.png
# ./outputs_model_1/sandstone/image272.png
# ./outputs_model_1/sandstone/image273.png
# ./outputs_model_1/sandstone/image274.png
# ./outputs_model_1/sandstone/image275.png
# ./outputs_model_1/sandstone/image276.png
# ./outputs_model_1/sandstone/image277.png
# ./outputs_model_1/sandstone/image278.png
# ./outputs_model_1/sandstone/image279.png
# ./outputs_model_1/sandstone/image280.png
# ./outputs_model_1/sandstone/image281.png
# ./outputs_model_1/sandstone/image282.png
# ./outputs_model_1/sandstone/image283.png
# ./outputs_model_1/sandstone/image284.png
# ./outputs_model_1/sandstone/image285.png
# ./outputs_model_1/sandstone/image286.png
# ./outputs_model_1/sandstone/image287.png
# ./outputs_model_1/sandstone/image288.png
# ./outputs_model_1/sandstone/image289.png
# ./outputs_model_1/sandstone/image290.png
# ./outputs_model_1/sandstone/image291.png
# ./outputs_model_1/sandstone/image292.png
# ./outputs_model_1/sandstone/image293.png
# ./outputs_model_1/sandstone/image294.png
# ./outputs_model_1/sandstone/image295.png
# ./outputs_model_1/sandstone/image296.png
# ./outputs_model_1/sandstone/image297.png
# ./outputs_model_1/sandstone/image298.png
# ./outputs_model_1/sandstone/image299.png
# ./outputs_model_1/sandstone/image300.png
# ./outputs_model_1/sandstone/image301.png
# ./outputs_model_1/sandstone/image302.png
# ./outputs_model_1/sandstone/image303.png
# ./outputs_model_1/sandstone/image304.png
# ./outputs_model_1/sandstone/image305.png
# ./outputs_model_1/sandstone/image306.png
# ./outputs_model_1/sandstone/image307.png
# ./outputs_model_1/sandstone/image308.png
# ./outputs_model_1/sandstone/image309.png
# ./outputs_model_1/sandstone/image310.png
# ./outputs_model_1/sandstone/image311.png
# ./outputs_model_1/sandstone/image312.png
# ./outputs_model_1/sandstone/image313.png
# ./outputs_model_1/sandstone/image314.png
# ./outputs_model_1/sandstone/image315.png
# ./outputs_model_1/sandstone/image316.png
# ./outputs_model_1/sandstone/image317.png
# ./outputs_model_1/sandstone/image318.png
# ./outputs_model_1/sandstone/image319.png
# ./outputs_model_1/sandstone/image320.png
# ./outputs_model_1/sandstone/image321.png
# ./outputs_model_1/sandstone/image322.png
# ./outputs_model_1/sandstone/image323.png
# ./outputs_model_1/sandstone/image324.png
# ./outputs_model_1/sandstone/image325.png
# ./outputs_model_1/sandstone/image326.png
# ./outputs_model_1/sandstone/image327.png
# ./outputs_model_1/sandstone/image328.png
# ./outputs_model_1/sandstone/image329.png
# ./outputs_model_1/sandstone/image330.png
# ./outputs_model_1/sandstone/image331.png
# ./outputs_model_1/sandstone/image332.png
# ./outputs_model_1/sandstone/image333.png
# ./outputs_model_1/sandstone/image334.png
# ./outputs_model_1/sandstone/image335.png
# ./outputs_model_1/sandstone/image336.png
# ./outputs_model_1/sandstone/image337.png
# ./outputs_model_1/sandstone/image338.png
# ./outputs_model_1/sandstone/image339.png
# ./outputs_model_1/sandstone/image340.png
# ./outputs_model_1/sandstone/image341.png
# ./outputs_model_1/sandstone/image342.png
# ./outputs_model_1/sandstone/image343.png
# ./outputs_model_1/sandstone/image344.png
# ./outputs_model_1/sandstone/image345.png
# ./outputs_model_1/sandstone/image346.png
# ./outputs_model_1/sandstone/image347.png
# ./outputs_model_1/sandstone/image348.png
# ./outputs_model_1/sandstone/image349.png
# ./outputs_model_1/sandstone/image350.png
# ./outputs_model_1/sandstone/image351.png
# ./outputs_model_1/sandstone/image352.png
# ./outputs_model_1/sandstone/image353.png
# ./outputs_model_1/sandstone/image354.png
# ./outputs_model_1/sandstone/image355.png
# ./outputs_model_1/sandstone/image356.png
# ./outputs_model_1/sandstone/image357.png
# ./outputs_model_1/sandstone/image358.png
# ./outputs_model_1/sandstone/image359.png
# ./outputs_model_1/sandstone/image360.png
# ./outputs_model_1/sandstone/image361.png
# ./outputs_model_1/sandstone/image362.png
# ./outputs_model_1/sandstone/image363.png
# ./outputs_model_1/sandstone/image364.png
# ./outputs_model_1/sandstone/image365.png
# ./outputs_model_1/sandstone/image366.png
# ./outputs_model_1/sandstone/image367.png
# ./outputs_model_1/sandstone/image368.png
# ./outputs_model_1/sandstone/image369.png
# ./outputs_model_1/sandstone/image370.png
# ./outputs_model_1/sandstone/image371.png
# ./outputs_model_1/sandstone/image372.png
# ./outputs_model_1/sandstone/image373.png
# ./outputs_model_1/sandstone/image374.png
# ./outputs_model_1/sandstone/image375.png
# ./outputs_model_1/sandstone/image376.png
# ./outputs_model_1/sandstone/image377.png
# ./outputs_model_1/sandstone/image378.png
# ./outputs_model_1/sandstone/image379.png
# ./outputs_model_1/sandstone/image380.png
# ./outputs_model_1/sandstone/image381.png
# ./outputs_model_1/sandstone/image382.png
# ./outputs_model_1/sandstone/image383.png
# ./outputs_model_1/sandstone/image384.png
# ./outputs_model_1/sandstone/image385.png
# ./outputs_model_1/sandstone/image386.png
# ./outputs_model_1/sandstone/image387.png
# ./outputs_model_1/sandstone/image388.png
# ./outputs_model_1/sandstone/image389.png
# ./outputs_model_1/sandstone/image390.png
# ./outputs_model_1/sandstone/image391.png
# ./outputs_model_1/sandstone/image392.png
# ./outputs_model_1/sandstone/image393.png
# ./outputs_model_1/sandstone/image394.png
# ./outputs_model_1/sandstone/image395.png
# ./outputs_model_1/sandstone/image396.png
# ./outputs_model_1/sandstone/image397.png
# ./outputs_model_1/sandstone/image398.png
# ./outputs_model_1/sandstone/image399.png
# ./outputs_model_1/sandstone/image400.png
# ./outputs_model_1/sandstone/image401.png
# ./outputs_model_1/sandstone/image402.png
# ./outputs_model_1/sandstone/image403.png
# ./outputs_model_1/sandstone/image404.png
# ./outputs_model_1/sandstone/image405.png
# ./outputs_model_1/sandstone/image406.png
# ./outputs_model_1/sandstone/image407.png
# ./outputs_model_1/sandstone/image408.png
# ./outputs_model_1/sandstone/image409.png
# ./outputs_model_1/sandstone/image410.png
# ./outputs_model_1/sandstone/image411.png
# ./outputs_model_1/sandstone/image412.png
# ./outputs_model_1/sandstone/image413.png
# ./outputs_model_1/sandstone/image414.png
# ./outputs_model_1/sandstone/image415.png
# ./outputs_model_1/sandstone/image416.png
# ./outputs_model_1/sandstone/image417.png
# ./outputs_model_1/sandstone/image418.png
# ./outputs_model_1/sandstone/image419.png
# ./outputs_model_1/sandstone/image420.png
# ./outputs_model_1/sandstone/image421.png
# ./outputs_model_1/sandstone/image422.png
# ./outputs_model_1/sandstone/image423.png
# ./outputs_model_1/sandstone/image424.png
# ./outputs_model_1/sandstone/image425.png
# ./outputs_model_1/sandstone/image426.png
# ./outputs_model_1/sandstone/image427.png
# ./outputs_model_1/sandstone/image428.png
# ./outputs_model_1/sandstone/image429.png
# ./outputs_model_1/sandstone/image430.png
# ./outputs_model_1/sandstone/image431.png
# ./outputs_model_1/sandstone/image432.png
# ./outputs_model_1/sandstone/image433.png
# ./outputs_model_1/sandstone/image434.png
# ./outputs_model_1/sandstone/image435.png
# ./outputs_model_1/sandstone/image436.png
# ./outputs_model_1/sandstone/image437.png
# ./outputs_model_1/sandstone/image438.png
# ./outputs_model_1/sandstone/image439.png
# ./outputs_model_1/sandstone/image440.png
# ./outputs_model_1/sandstone/image441.png
# ./outputs_model_1/sandstone/image442.png
# ./outputs_model_1/sandstone/image443.png
# ./outputs_model_1/sandstone/image444.png
# ./outputs_model_1/sandstone/image445.png
# ./outputs_model_1/sandstone/image446.png
# ./outputs_model_1/sandstone/image447.png
# ./outputs_model_1/sandstone/image448.png
# ./outputs_model_1/sandstone/image449.png
# ./outputs_model_1/sandstone/image450.png
# ./outputs_model_1/sandstone/image451.png
# ./outputs_model_1/sandstone/image452.png
# ./outputs_model_1/sandstone/image453.png
# ./outputs_model_1/sandstone/image454.png
# ./outputs_model_1/sandstone/image455.png
# ./outputs_model_1/sandstone/image456.png
# ./outputs_model_1/sandstone/image457.png
# ./outputs_model_1/sandstone/image458.png
# ./outputs_model_1/sandstone/image459.png
# ./outputs_model_1/sandstone/image460.png
# ./outputs_model_1/sandstone/image461.png
# ./outputs_model_1/sandstone/image462.png
# ./outputs_model_1/sandstone/image463.png
# ./outputs_model_1/sandstone/image464.png
# ./outputs_model_1/sandstone/image465.png
# ./outputs_model_1/sandstone/image466.png
# ./outputs_model_1/sandstone/image467.png
# ./outputs_model_1/sandstone/image468.png
# ./outputs_model_1/sandstone/image469.png
# ./outputs_model_1/sandstone/image470.png
# ./outputs_model_1/sandstone/image471.png
# ./outputs_model_1/sandstone/image472.png
# ./outputs_model_1/sandstone/image473.png
# ./outputs_model_1/sandstone/image474.png
# ./outputs_model_1/sandstone/image475.png
# ./outputs_model_1/sandstone/image476.png
# ./outputs_model_1/sandstone/image477.png
# ./outputs_model_1/sandstone/image478.png
# ./outputs_model_1/sandstone/image479.png
# ./outputs_model_1/sandstone/image480.png
# ./outputs_model_1/sandstone/image481.png
# ./outputs_model_1/sandstone/image482.png
# ./outputs_model_1/sandstone/image483.png
# ./outputs_model_1/sandstone/image484.png
# ./outputs_model_1/sandstone/image485.png
# ./outputs_model_1/sandstone/image486.png
# ./outputs_model_1/sandstone/image487.png
# ./outputs_model_1/sandstone/image488.png
# ./outputs_model_1/sandstone/image489.png
# ./outputs_model_1/sandstone/image490.png
# ./outputs_model_1/sandstone/image491.png
# ./outputs_model_1/sandstone/image492.png
# ./outputs_model_1/sandstone/image493.png
# ./outputs_model_1/sandstone/image494.png
# ./outputs_model_1/sandstone/image495.png
# ./outputs_model_1/sandstone/image496.png
# ./outputs_model_1/sandstone/image497.png
# ./outputs_model_1/sandstone/image498.png
# ./outputs_model_1/sandstone/image499.png

# %%
import glob
from skimage.io import imread, imsave
import matplotlib.pyplot as plt
import numpy as np

def crop_center(img, cropx, cropy):
       y, x = img.shape
       startx = x // 2 - (cropx // 2)
       starty = y // 2 - (cropy // 2)
       return img[starty:starty + cropy, startx:startx + cropx]

output_path = "./data/BeadPack/val_segmentation_500/"
img_names = sorted(glob.glob("./data/BeadPack/val_segmentation/*.png"))
img_names

for name in img_names:
    print(name)
    im = imread(name)
    print(im.shape)
    im = crop_center(im,500,500)
    print(im.shape)
    out_name = name.split("/")[-1]
    imsave(output_path+out_name,im)
# Out:
# ./data/BeadPack/val_segmentation/image_0400.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0401.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0402.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0403.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0404.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0400.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0401.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0402.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0403.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0404.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0405.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0406.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0407.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0408.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0409.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0405.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0406.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0407.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0408.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0409.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0410.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0411.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0412.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0413.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0414.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0410.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0411.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0412.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0413.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0414.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0415.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0416.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0417.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0418.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0419.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0415.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0416.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0417.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0418.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0419.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0420.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0421.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0422.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0423.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0424.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0420.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0421.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0422.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0423.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0424.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0425.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0426.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0427.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0428.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0429.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0425.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0426.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0427.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0428.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0429.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0430.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0431.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0432.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0433.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0434.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0430.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0431.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0432.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0433.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0434.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0435.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0436.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0437.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0438.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0439.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0435.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0436.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0437.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0438.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0439.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0440.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0441.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0442.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0443.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0444.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0440.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0441.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0442.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0443.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0444.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0445.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0446.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0447.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0448.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0449.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0445.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0446.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0447.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0448.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0449.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0450.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0451.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0452.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0453.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0454.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0450.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0451.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0452.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0453.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0454.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0455.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0456.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0457.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0458.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0459.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0455.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0456.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0457.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0458.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0459.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0460.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0461.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0462.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0463.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0464.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0465.png
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0460.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0461.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0462.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0463.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0464.png is a low contrast image
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0466.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0467.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0468.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0469.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0470.png
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0465.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0466.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0467.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0468.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0469.png is a low contrast image
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0471.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0472.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0473.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0474.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0475.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0470.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0471.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0472.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0473.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0474.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0475.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0476.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0477.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0478.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0479.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0480.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0476.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0477.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0478.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0479.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0480.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0481.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0482.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0483.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0484.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0485.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0486.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0481.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0482.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0483.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0484.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0485.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0486.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0487.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0488.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0489.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0490.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0491.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0487.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0488.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0489.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0490.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0491.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0492.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0493.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0494.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0495.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0496.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0492.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0493.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0494.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0495.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0496.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0497.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0498.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0499.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0500.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0501.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0497.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0498.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0499.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0500.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0501.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0502.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0503.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0504.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0505.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0506.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0502.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0503.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0504.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0505.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0506.png is a low contrast image
# ./data/BeadPack/val_segmentation/image_0507.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0508.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0509.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0510.png
# (512, 512)
# (500, 500)
# ./data/BeadPack/val_segmentation/image_0511.png
# (512, 512)
# (500, 500)
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0507.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0508.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0509.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0510.png is a low contrast image
# /home/users/tperciano/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:23: UserWarning: ./data/BeadPack/val_segmentation_500/image_0511.png is a low contrast image

# %%
from crfrnn_layer import CrfRnnLayer
from keras.models import Model
from keras_segmentation.models.model_utils import get_segmentation_model

""" Returns Keras CRN-RNN model definition.

Currently, only 500 x 500 images are supported. However, one can get this to
work with different image sizes by adjusting the parameters of the Cropping2D layers
below.
"""

channels, height, width = 3, 500, 500

n_classes = 2 #21

# Input
input_shape = (height, width, 3)
img_input = Input(shape=input_shape)

# Add plenty of zero padding
x = ZeroPadding2D(padding=(100, 100))(img_input)

# VGG-16 convolution block 1
x = Conv2D(64, (3, 3), activation='relu', padding='valid', name='conv1_1')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', name='conv1_2')(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='pool1')(x)

# VGG-16 convolution block 2
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='conv2_1')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', name='conv2_2')(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='pool2', padding='same')(x)

# VGG-16 convolution block 3
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='conv3_1')(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='conv3_2')(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', name='conv3_3')(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='pool3', padding='same')(x)
pool3 = x

# VGG-16 convolution block 4
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='conv4_1')(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='conv4_2')(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='conv4_3')(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='pool4', padding='same')(x)
pool4 = x

# VGG-16 convolution block 5
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='conv5_1')(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='conv5_2')(x)
x = Conv2D(512, (3, 3), activation='relu', padding='same', name='conv5_3')(x)
x = MaxPooling2D((2, 2), strides=(2, 2), name='pool5', padding='same')(x)

# Fully-connected layers converted to convolution layers
x = Conv2D(4096, (7, 7), activation='relu', padding='valid', name='fc6')(x)
x = Dropout(0.5)(x)
x = Conv2D(4096, (1, 1), activation='relu', padding='valid', name='fc7')(x)
x = Dropout(0.5)(x)
x = Conv2D(n_classes, (1, 1), padding='valid', name='score-fr')(x)

# Deconvolution
score2 = Conv2DTranspose(n_classes, (4, 4), strides=2, name='score2')(x)

# Skip connections from pool4
score_pool4 = Conv2D(n_classes, (1, 1), name='score-pool4')(pool4)
score_pool4c = Cropping2D((5, 5))(score_pool4)
score_fused = Add()([score2, score_pool4c])
score4 = Conv2DTranspose(n_classes, (4, 4), strides=2, name='score4', use_bias=False)(score_fused)

# Skip connections from pool3
score_pool3 = Conv2D(n_classes, (1, 1), name='score-pool3')(pool3)
score_pool3c = Cropping2D((9, 9))(score_pool3)

# Fuse things together
score_final = Add()([score4, score_pool3c])

# Final up-sampling and cropping
upsample = Conv2DTranspose(n_classes, (16, 16), strides=8, name='upsample', use_bias=False)(score_final)
upscore = Cropping2D(((31, 37), (31, 37)))(upsample)

output = CrfRnnLayer(image_dims=(height, width),
                     num_classes=n_classes,
                     theta_alpha=160.,
                     theta_beta=3.,
                     theta_gamma=3.,
                     num_iterations=10,
                     name='crfrnn')([upscore, img_input])

# Build the model
#model_crfrnn = Model(img_input, output)
model_crfrnn = get_segmentation_model(img_input, output)

# %%
model_crfrnn.train(train_images = "data/BeadPack/train_images_500/", 
            train_annotations="data/BeadPack/train_segmentation_500/",
            checkpoints_path="checkpoints/model_crfrnn/",
            epochs=5)
# Out:
#   4%|▍         | 16/400 [00:00<00:02, 152.17it/s]
# Verifying training dataset
# 100%|██████████| 400/400 [00:02<00:00, 190.60it/s]
# Dataset verified!
# Epoch 1/5
# 333/512 [==================>...........] - ETA: 24:19 - loss: 0.6120 - accuracy: 0.6893
